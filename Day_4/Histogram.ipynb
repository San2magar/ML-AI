# %% [markdown]
# ## Making Histogram

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data=[1,3,3,3,3,9,9,4,4,8,8,8,6,7]

# %%
plt.hist(data)
plt.show()

# %% [markdown]
# ## Adding with bins

# %%
plt.figure(figsize=(2,2))
plt.hist(data, color='b', bins=3)
plt.show()

# %%
import pandas as pd

# %%
iris_df=pd.read_csv(r'D:\Data_science\Day_4\Data_sets\iris.csv')

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
plt.subplot(1,4,1)
plt.hist(iris_df['sepal_length'],bins=30,color="g")

plt.subplot(1,4,2)
plt.hist(iris_df['petal_length'],bins=30,color="r")

plt.subplot(1,4,3)
plt.hist(iris_df['sepal_width'],bins=30,color="b")

plt.subplot(1,4,4)
plt.hist(iris_df['petal_width'],bins=30,color="yellow")
# Out:
# (array([ 6., 28.,  7.,  7.,  0.,  1.,  1.,  0.,  0.,  0.,  0.,  7.,  3.,
#          5.,  0., 13.,  8., 12.,  4.,  2.,  0., 12.,  5.,  6.,  0.,  6.,
#          3.,  8.,  3.,  3.]),
#  array([0.1 , 0.18, 0.26, 0.34, 0.42, 0.5 , 0.58, 0.66, 0.74, 0.82, 0.9 ,
#         0.98, 1.06, 1.14, 1.22, 1.3 , 1.38, 1.46, 1.54, 1.62, 1.7 , 1.78,
#         1.86, 1.94, 2.02, 2.1 , 2.18, 2.26, 2.34, 2.42, 2.5 ]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ## creating a box plot

# %%
one=[1,2,3,4,5,6,7,8,9]
two=[1,2,3,4,5,4,3,2,1]
three=[6,7,8,9,8,7,6,5,4]
data=list([one,two,three])
plt.boxplot(data)
plt.show()

# %%
one=[1,2,3,4,5,6,7,8,9]
two=[1,2,3,4,5,4,3,2,1]
three=[6,7,8,9,8,7,6,5,4]
data=list([one,two,three])
plt.violinplot(data, showmedians=True)
plt.show()

# %% [markdown]
# ## Pie Charts

# %%
iris_df=pd.read_csv(r'D:\Data_science\Day_4\Data_sets\iris.csv')
quantity=iris_df['species'].value_counts()
plt.pie(quantity,labels=quantity.index ,autopct="%0.01f%%")
plt.show()

# %%
Fruits=['apple','Mangos','Banana','Litchi','Orange']
quantity=[53,43,12,97,80]
plt.pie(quantity,labels=Fruits, autopct="%0.01f%%",colors=["green",'yellow','red','orange','blue'])
plt.legend(loc='upper right',bbox_to_anchor=(2,1))
plt.show()

# %% [markdown]
# ## Donut Chart

# %%
Fruits=['apple','Mangos','Banana','Litchi','Orange']
quantity=[53,43,12,97,80]

# %%
plt.pie(quantity, labels=Fruits,
       autopct="%0.1f%%", colors=['green','yellow','blue','pink','orange'], radius=2)
plt.pie([5],colors="w", radius=1)
plt.show()

# %% [markdown]
# # Polar plot

# %%
import matplotlib.pyplot as plt
import numpy as np

r= np.linspace(0, 10, 100)
theta = 2 * np.pi * r

plt.figure(figsize=(6,6))
plt.subplot(111, projection="polar")
plt.plot(theta, r)
plt.title('Polar Plot')
plt.show()

# %% [markdown]
# ## Hexbin Plot

# %%
# Generate some random data
x = np.random.randn(1000)
y = np.random.randn(1000)

# create a hexbin plot
plt.hexbin(x,y,gridsize=30,cmap='Blues')
plt.title('Hexbin Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.colorbar(label="count")
plt.show()

# %% [markdown]
# ## Contour Plot

# %%
x = np.linspace(-3.0, 3.0, 100)
y = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(X**2 + Y**2)

# create a contour plot
plt.contour(X,Y,Z)
plt.title('Contour Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis') 
plt.colorbar(label='Z') # add a colorbar with label
plt.show()

# %% [markdown]
# # 3D Scatter Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# generate some random data
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

x = np.random.standard_normal(100)
y = np.random.standard_normal(100)
z = np.random.standard_normal(100)

# create a 3d scatter plot
ax.scatter(x,y,z)
ax.set_title('3D Scatter plot')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
plt.show()

# %% [markdown]
# ## Heat Map

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# generate some sample data
data= np.random.rand(10,12) # 10 x 12

# set up the matplotlib figure
plt.figure(figsize=(12,8))

# create a heatmap with seaborn
sns.heatmap(data,
           annot=True,
           fmt='.2f')
plt.show()
